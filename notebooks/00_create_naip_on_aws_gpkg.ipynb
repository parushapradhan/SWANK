# %% [markdown]
# ### NAIP On AWS
#
# This Jupyter notebook provides code to scrape the [NAIP on AWS](https://registry.opendata.aws/naip/) manifest and create a GPKG file that provides a geospatial footprint for all available imagery.
#
# Then, if we are interested in a given OSM ID, it's easy to look up which NAIP images intersect this ID and download them directly.

# %%
import pathlib

from tqdm import tqdm
from osgeo import ogr, osr
ogr.UseExceptions()

from rsc.common import aws_naip
from rsc.common.aws_naip import AWS_PATH

# Get NAIP manifest
manifest = aws_naip.get_naip_manifest()

# Filter out shapefiles to download
shp = [e for e in manifest if e.split('.')[-1].lower() in \
    ('shp', 'dbf', 'shx', 'prj', 'sbn')]

# Fetch all the shapefiles
for object_name in tqdm(shp):
    aws_naip.get_naip_file(object_name)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1315/1315 [14:49<00:00,  1.48it/s]

# %%
def conv(s: str) -> str:
    """ Convert object paths as seen in manifest to those that might be seen in the shapefiles.
        It's silly they don't match."""
    return '%s.tif' % '_'.join(s.split('_')[:6])

# Read the manifest, and convert the TIF files to those that might be seen in the shapefile metadata
with open(AWS_PATH / 'manifest.txt', 'r') as f:
    mani = {conv(pathlib.Path(p).stem): p for p in (e.strip() for e in f.readlines()) if p.endswith('.tif')}

# %%
# Do all the work!

# Create SRS (EPSG:4326: WGS-84 decimal degrees)
srs = osr.SpatialReference()
srs.ImportFromEPSG(4326)
srs.SetAxisMappingStrategy(osr.OAMS_TRADITIONAL_GIS_ORDER)

# Create GPKG file for writing
driver: ogr.Driver = ogr.GetDriverByName('GPKG')
ds_w: ogr.DataSource = driver.CreateDataSource(str(AWS_PATH / 'naip_on_aws_all_states.gpkg'))
layer_w: ogr.Layer = ds_w.CreateLayer('footprints', srs=srs, geom_type=ogr.wkbPolygon)

# Define output fields
state_field = ogr.FieldDefn('STATE', ogr.OFTString)
band_field = ogr.FieldDefn('BAND', ogr.OFTString)
usgs_id_field = ogr.FieldDefn('USGSID', ogr.OFTString)
src_img_date_field = ogr.FieldDefn('SRCIMGDATE', ogr.OFTString)
filename_field = ogr.FieldDefn('FILENAME', ogr.OFTString)
object_field = ogr.FieldDefn('OBJECT', ogr.OFTString)

# Create output fields in layer
layer_w.CreateField(state_field)
layer_w.CreateField(band_field)
layer_w.CreateField(usgs_id_field)
layer_w.CreateField(src_img_date_field)
layer_w.CreateField(filename_field)
layer_w.CreateField(object_field)

# Get layer feature definition to load in features
feat_defn = layer_w.GetLayerDefn()

# Helper function to safely get field values
def get_field_safe(feat, field_names, fallback=""):
    """
    Safely get a field value, trying multiple possible field names.
    
    Args:
        feat: OGR feature
        field_names: List of field names to try
        fallback: Default value if no field is found
    
    Returns:
        Field value or fallback
    """
    for field_name in field_names:
        try:
            value = feat.GetFieldAsString(field_name)
            if value:  # Only return if we got a non-empty value
                return value
        except RuntimeError:
            continue
    return fallback

# Statistics tracking
total_features = 0
features_processed = 0
features_skipped = 0
state_counts = {}

# Loop through all fetched shapefiles
all_shapefiles = list(AWS_PATH.rglob('*.shp'))
print(f'Processing {len(all_shapefiles)} shapefiles...')

for p in all_shapefiles:
    print(f'\nProcessing: {p.name}')
    
    # Load them in OGR, get layer and spatial reference
    ds_r: ogr.DataSource = ogr.Open(str(p))
    layer_r: ogr.Layer = ds_r.GetLayer()
    srs_r: osr.SpatialReference = layer_r.GetSpatialRef()
    srs_r.SetAxisMappingStrategy(osr.OAMS_TRADITIONAL_GIS_ORDER)

    # Debug: Print available fields for first feature (optional)
    if total_features == 0:
        feat_debug = layer_r.GetNextFeature()
        if feat_debug:
            feat_defn_debug = feat_debug.GetDefnRef()
            field_count = feat_defn_debug.GetFieldCount()
            print("Available fields in first feature:")
            for i in range(field_count):
                field_defn = feat_defn_debug.GetFieldDefn(i)
                field_name = field_defn.GetName()
                print(f"  {i}: {field_name}")
            layer_r.ResetReading()  # Reset to beginning

    # Loop through the features in the layer
    for _ in range(layer_r.GetFeatureCount()):
        feat_r: ogr.Feature = layer_r.GetNextFeature()
        total_features += 1

        # Quickly crosscheck with manifest. Skip if not in there
        filename = get_field_safe(feat_r, ['FileName', 'FILENAME'])
        if not filename:
            features_skipped += 1
            continue
            
        filename_conv = conv(filename.split('.')[0])
        if not filename_conv in mani:
            features_skipped += 1
            continue

        # Parse remaining metadata with robust field handling
        state = get_field_safe(feat_r, ['ST', 'QUADST', 'STATE'])
        if not state:
            features_skipped += 1
            continue
            
        # Track state counts
        if state not in state_counts:
            state_counts[state] = 0
        state_counts[state] += 1
        
        # Get band information with robust field handling
        band = get_field_safe(feat_r, ['Band', 'BAND'])
        if not band:
            features_skipped += 1
            continue
        
        usgs_id = get_field_safe(feat_r, ['USGSID', 'USGS_ID'])
        src_img_date = get_field_safe(feat_r, ['SrcImgDate', 'SRCIMGDATE', 'DATE'])

        # Fetch geometry and convert to desired spatial reference
        try:
            trans = osr.CoordinateTransformation(srs_r, srs)
            geom = ogr.CreateGeometryFromWkt(feat_r.GetGeometryRef().ExportToWkt())
            geom.Transform(trans)
        except Exception as e:
            print(f"Geometry error in {p.name}: {e}")
            features_skipped += 1
            continue

        # Create our new feature
        feat_w = ogr.Feature(feat_defn)
        feat_w.SetGeometry(geom)
        feat_w.SetField('STATE', state)
        feat_w.SetField('BAND', band)
        feat_w.SetField('USGSID', usgs_id)
        feat_w.SetField('SRCIMGDATE', src_img_date)
        feat_w.SetField('FILENAME', filename)
        feat_w.SetField('OBJECT', mani[filename_conv])

        # Save!
        layer_w.CreateFeature(feat_w)
        features_processed += 1

        # Cleanup features
        feat_w = None
        feat_r = None

    # Cleanup read dataset
    layer_r = None
    ds_r = None

# Cleanup write dataset
layer_w = None
ds_w = None

# Print summary statistics
print(f'\nProcessing complete!')
print(f'Total features examined: {total_features}')
print(f'Features processed: {features_processed}')
print(f'Features skipped: {features_skipped}')
print(f'Success rate: {features_processed/total_features*100:.1f}%')
print(f'\nFeatures by state:')
for state, count in sorted(state_counts.items()):
    print(f'  {state}: {count}')
print(f'\nOutput saved to: {AWS_PATH / "naip_on_aws_all_states.gpkg"}')
# Out:
# Processing 263 shapefiles...
#
# Processing: naip_nm_2011_1m_m4b.shp
# Available fields in first feature:
#   0: AREA
#   1: PERIMETER
#   2: ST
#   3: QQNAME
#   4: QKEY
#   5: QUADRANT
#   6: APFONAME
#   7: GNIS
#   8: DY
#   9: MY
#   10: SY
#   11: DX
#   12: MX
#   13: SX
#   14: OLAT
#   15: OLONG
#   16: ArcKey
#   17: Band
#   18: USGSID
#   19: Qdrnt
#   20: UTM
#   21: Res
#   22: SrcImgDate
#   23: VerDate
#   24: FileName
#
# Processing: naip_3_14_1_2_nm.shp
#
# Processing: naip_3_16_1_2_nm.shp
#
# Processing: NAIP_20_NM.shp
#
# Processing: NAIP_18_NM.shp
#
# Processing: naip_de_2011_1m_m4b.shp
#
# Processing: DE_NAIP21_QQ.shp
#
# Processing: naip_3_13_2_7_de.shp
#
# Processing: NAIP_18_DE.shp
#
# Processing: naip_3_17_2_5_de.shp
#
# Processing: naip_3_15_2_8_de.shp
#
# Processing: naip_oh_2011_1m_m4b.shp
#
# Processing: OH_NAIP21_QQ.shp
#
# Processing: NAIP_19_OH.shp
#
# Processing: naip_3_13_3_8_oh.shp
#
# Processing: naip_3_17_2_1_oh.shp
#
# Processing: naip_3_15_2_4_oh.shp
#
# Processing: naip_ia_2011_1m_m4b.shp
#
# Processing: naip_3_14_3_2_ia.shp
#
# Processing: IA_NAIP21_QQ.shp
#
# Processing: NAIP_19_IA.shp
#
# Processing: naip_3_13_3_4_ia.shp
#
# Processing: naip_3_17_3_4_ia.shp
#
# Processing: naip_3_15_3_4_ia.shp
#
# Processing: naip_3_14_3_4_mo.shp
#
# Processing: naip_3_16_3_5_mo.shp
#
# Processing: NAIP_20_MO.shp
#
# Processing: NAIP_18_MO.shp
#
# Processing: naip_3_12_3_4_mo.shp
#
# Processing: naip_3_14_2_7_mi.shp
#
# Processing: naip_3_16_2_4_mi.shp
#
# Processing: NAIP_20_MI.shp
#
# Processing: NAIP_18_MI.shp
#
# Processing: naip_3_12_2_3_mi.shp
#
# Processing: naip_3_14_1_1_ne.shp
#
# Processing: naip_3_16_3_2_ne.shp
#
# Processing: NAIP_20_NE.shp
#
# Processing: NAIP_18_NE.shp
#
# Processing: naip_3_12_1_3_ne.shp
#
# Processing: naip_3_14_2_6_ma.shp
#
# Processing: naip_3_16_2_3_ma.shp
#
# Processing: MA_NAIP21_QQ.shp
#
# Processing: NAIP_18_MA.shp
#
# Processing: naip_3_12_2_2_ma.shp
#
# Processing: OK_NAIP21_QQ.shp
#
# Processing: NAIP_19_OK.shp
#
# Processing: naip_3_13_3_6_ok.shp
#
# Processing: naip_3_17_3_2_ok.shp
#
# Processing: naip_3_15_2_5_ok.shp
#
# Processing: HI_NAIP21_QQ.shp
#
# Processing: naip_3_14_1_6_tx.shp
#
# Processing: naip_3_16_1_6_tx.shp
#
# Processing: NAIP_20_TX.shp
#
# Processing: NAIP_18_TX.shp
#
# Processing: naip_3_12_1_5_tx.shp
#
# Processing: naip_co_2011_1m_m4b.shp
#
# Processing: CO_NAIP21_QQ.shp
#
# Processing: NAIP_19_CO.shp
#
# Processing: naip_3_13_3_3_co.shp
#
# Processing: naip_3_17_1_4_co.shp
#
# Processing: naip_3_15_1_5_co.shp
#
# Processing: naip_3_14_2_11_tn.shp
#
# Processing: naip_3_16_1_5_tn.shp
#
# Processing: TN_NAIP21_QQ.shp
#
# Processing: NAIP_18_TN.shp
#
# Processing: naip_3_12_3_7_tn.shp
#
# Processing: naip_3_14_3_3_ms.shp
#
# Processing: naip_3_16_3_4_ms.shp
#
# Processing: NAIP_20_MS.shp
#
# Processing: MS_NAIP21_QQ.shp
#
# Processing: NAIP_18_MS.shp
#
# Processing: naip_3_12_3_3_ms.shp
#
# Processing: AR_NAIP21_QQ.shp
#
# Processing: NAIP_19_AR.shp
#
# Processing: naip_3_13_3_2_ar.shp
#
# Processing: naip_3_17_3_3_ar.shp
#
# Processing: naip_3_15_1_4_ar.shp
#
# Processing: naip_il_2011_1m_m4b.shp
#
# Processing: naip_3_14_2_2_il.shp
#
# Processing: IL_NAIP21_QQ.shp
#
# Processing: NAIP_19_IL.shp
#
# Processing: naip_3_12_3_1_il.shp
#
# Processing: naip_3_17_3_7_il.shp
#
# Processing: naip_3_15_3_1_il.shp
#
# Processing: naip_3_14_1_5_sd.shp
#
# Processing: naip_3_16_3_3_sd.shp
#
# Processing: NAIP_20_sd.shp
#
# Processing: SD_NAIP21_QQ.shp
#
# Processing: NAIP_18_SD.shp
#
# Processing: naip_3_12_2_6_sd.shp
#
# Processing: naip_or_2011_1m_m4b.shp
#
# Processing: naip_3_14_1_4_or.shp
#
# Processing: naip_3_16_1_3_or.shp
#
# Processing: NAIP_20_OR.shp
#
# Processing: naip_3_12_1_4_or.shp
#
# Processing: LA_NAIP21_QQ.shp
#
# Processing: NAIP_19_LA.shp
#
# Processing: naip_3_13_3_5_la.shp
#
# Processing: naip_3_17_3_9_la.shp
#
# Processing: naip_3_15_1_2_la.shp
#
# Processing: NAIP_19_NV.shp
#
# Processing: naip_3_13_3_7_nv.shp
#
# Processing: naip_3_17_1_5_nv.shp
#
# Processing: naip_3_15_1_3_nv.shp
#
# Processing: NAIP_20_WI.shp
#
# Processing: naip_3_13_1_4_wi.shp
#
# Processing: NAIP_18_WI.shp
#
# Processing: naip_wi_2017_100_m4b.shp
#
# Processing: naip_3_15_3_6_wi.shp
#
# Processing: GA_NAIP21_QQ.shp
#
# Processing: NAIP_19_GA.shp
#
# Processing: naip_3_13_2_3_ga.shp
#
# Processing: naip_3_17_2_3_ga.shp
#
# Processing: naip_3_15_2_9_ga.shp
#
# Processing: naip_nh_2011_1m_m4b.shp
#
# Processing: naip_3_14_2_8_nh.shp
#
# Processing: naip_3_16_2_5_nh.shp
#
# Processing: NH_NAIP21_QQ.shp
#
# Processing: NAIP_18_NH.shp
#
# Processing: naip_3_12_2_4_nh.shp
#
# Processing: naip_3_14_2_3_in.shp
#
# Processing: naip_3_16_3_1_in.shp
#
# Processing: NAIP_20_IN.shp
#
# Processing: NAIP_18_IN.shp
#
# Processing: naip_3_12_3_2_in.shp
#
# Processing: naip_3_14_3_1_ca.shp
#
# Processing: naip_3_16_1_1_ca.shp
#
# Processing: NAIP_20_CA.shp
#
# Processing: NAIP_18_CA.shp
#
# Processing: naip_3_12_1_1_ca.shp
#
# Processing: naip_3_14_1_3_nd.shp
#
# Processing: naip_3_16_3_6_nd.shp
#
# Processing: NAIP_20_ND.shp
#
# Processing: ND_NAIP21_QQ.shp
#
# Processing: NAIP_19_ND.shp
#
# Processing: NAIP_18_ND.shp
#
# Processing: naip_3_12_1_7_nd.shp
#
# Processing: naip_3_17_1_6_nd.shp
#
# Processing: naip_3_15_1_10_nd.shp
#
# Processing: NAIP_19_PA.shp
#
# Processing: naip_3_13_2_6_pa.shp
#
# Processing: naip_pa_2017_100_m4b.shp
#
# Processing: naip_3_15_2_6_pa.shp
#
# Processing: naip_me_2011_1m_m4b.shp
#
# Processing: ME_NAIP21_QQ.shp
#
# Processing: naip_3_13_2_8_me.shp
#
# Processing: NAIP_18_ME.shp
#
# Processing: naip_3_15_2_10_me.shp
#
# Processing: naip_md_2011_1m_m4b.shp
#
# Processing: MD_NAIP21_QQ.shp
#
# Processing: naip_3_13_2_9_md.shp
#
# Processing: NAIP_18_MD.shp
#
# Processing: naip_3_17_3_7_md.shp
#
# Processing: naip_3_15_2_2_md.shp
#
# Processing: naip_3_14_2_4_ks.shp
#
# Processing: KS_NAIP21_QQ.shp
#
# Processing: NAIP_19_KS.shp
#
# Processing: naip_3_12_1_2_ks.shp
#
# Processing: naip_3_17_3_8_ks.shp
#
# Processing: naip_3_15_3_5_ks.shp
#
# Processing: naip_wv_2011_1m_m4b.shp
#
# Processing: naip_3_14_2_14_wv.shp
#
# Processing: naip_3_16_2_10_wv.shp
#
# Processing: NAIP_20_WV.shp
#
# Processing: NAIP_18_WV.shp
#
# Processing: naip_vt_2011_1m_m4b.shp
#
# Processing: naip_3_14_2_12_vt.shp
#
# Processing: naip_3_16_2_8_vt.shp
#
# Processing: VT_NAIP21_QQ.shp
#
# Processing: NAIP_18_VT.shp
#
# Processing: naip_3_12_2_7_vt.shp
#
# Processing: naip_ny_2011_1m_m4b.shp
#
# Processing: NY_NAIP21_QQ.shp
#
# Processing: NAIP_19_NY.shp
#
# Processing: naip_3_13_2_5_ny.shp
#
# Processing: naip_3_17_2_9_ny.shp
#
# Processing: naip_3_15_2_3_ny.shp
#
# Processing: naip_id_2011_1m_m4b.shp
#
# Processing: ID_NAIP21_QQ.shp
#
# Processing: NAIP_19_ID.shp
#
# Processing: naip_3_13_1_5_id.shp
#
# Processing: naip_3_17_1_1_id.shp
#
# Processing: naip_3_15_1_6_id_phd3.shp
#
# Processing: naip_3_15_1_6_id.shp
#
# Processing: naip_3_14_2_5_ky.shp
#
# Processing: naip_3_16_2_2_ky.shp
#
# Processing: NAIP_20_KY.shp
#
# Processing: NAIP_18_KY.shp
#
# Processing: naip_3_12_2_8_ky.shp
#
# Processing: AZ_NAIP21_QQ.shp
#
# Processing: NAIP_19_AZ.shp
#
# Processing: naip_3_13_3_1_az.shp
#
# Processing: naip_3_17_3_1_az.shp
#
# Processing: naip_3_15_1_1_az.shp
#
# Processing: naip_va_2011_1m_m4b.shp
#
# Processing: naip_3_14_2_13_va.shp
#
# Processing: naip_3_16_2_9_va.shp
#
# Processing: VA_NAIP21_QQ.shp
#
# Processing: NAIP_18_VA.shp
#
# Processing: naip_3_12_3_6_va.shp
#
# Processing: MN_NAIP21_QQ.shp
#
# Processing: NAIP_19_MN.shp
#
# Processing: naip_3_13_1_1_mn.shp
#
# Processing: naip_3_17_3_5_mn.shp
#
# Processing: naip_3_15_1_7_mn.shp
#
# Processing: naip_mt_2011_1m_m4b.shp
#
# Processing: MT_NAIP21_QQ.shp
#
# Processing: NAIP_19_MT.shp
#
# Processing: naip_3_13_1_2_mt.shp
#
# Processing: naip_3_17_1_2_mt.shp
#
# Processing: naip_3_15_1_8_mt.shp
#
# Processing: naip_3_15_1_8_mt_phd7.shp
#
# Processing: naip_3_14_2_9_nc.shp
#
# Processing: naip_3_16_2_6_nc.shp
#
# Processing: NAIP_20_NC.shp
#
# Processing: NAIP_18_NC.shp
#
# Processing: naip_3_12_3_5_nc.shp
#
# Processing: naip_ut_2011_1m_m4b.shp
#
# Processing: naip_3_14_3_5_ut.shp
#
# Processing: naip_3_16_1_4_ut.shp
#
# Processing: UT_NAIP21_QQ.shp
#
# Processing: NAIP_18_UT.shp
#
# Processing: naip_3_14_2_10_ri.shp
#
# Processing: naip_3_16_2_7_ri.shp
#
# Processing: RI_NAIP21_QQ.shp
#
# Processing: NAIP_18_RI.shp
#
# Processing: naip_3_12_2_5_ri.shp
#
# Processing: FL_NAIP21_QQ.shp
#
# Processing: NAIP_19_FL.shp
#
# Processing: naip_3_13_2_2_fl.shp
#
# Processing: naip_3_17_2_6_fl.shp
#
# Processing: naip_3_15_2_1_fl.shp
#
# Processing: naip_sc_2011_1m_m4b.shp
#
# Processing: SC_NAIP21_QQ.shp
#
# Processing: NAIP_19_SC.shp
#
# Processing: naip_3_13_2_10_sc.shp
#
# Processing: naip_sc_2017_100_m4b.shp
#
# Processing: naip_3_15_2_7_sc.shp
#
# Processing: naip_al_2011_1m_m4b.shp
#
# Processing: AL_NAIP21_QQ.shp
#
# Processing: NAIP_19_AL.shp
#
# Processing: naip_3_13_2_1_al.shp
#
# Processing: naip_3_17_2_4_al.shp
#
# Processing: naip_3_15_3_3_al.shp
#
# Processing: NAIP_19_WY.shp
#
# Processing: naip_3_12_1_6_wy.shp
#
# Processing: naip_3_17_1_3_wy.shp
#
# Processing: naip_3_15_3_2_wy.shp
#
# Processing: NAIP_19_NJ.shp
#
# Processing: naip_3_13_2_4_nj.shp
#
# Processing: naip_3_17_2_7_nj.shp
#
# Processing: naip_3_15_2_11_nj.shp
#
# Processing: naip_wa_2011_1m_m4b.shp
#
# Processing: WA_NAIP21_QQ.shp
#
# Processing: NAIP_19_WA.shp
#
# Processing: naip_3_13_1_3_wa.shp
#
# Processing: naip_3_17_1_8_wa.shp
#
# Processing: naip_3_15_1_9_wa.shp
#
# Processing: naip_3_14_2_1_ct.shp
#
# Processing: naip_3_16_2_1_ct.shp
#
# Processing: CT_NAIP21_QQ.shp
#
# Processing: NAIP_18_CT.shp
#
# Processing: naip_3_12_2_1_ct.shp
#
# Processing complete!
# Total features examined: 1173744
# Features processed: 1049321
# Features skipped: 124423
# Success rate: 89.4%
#
# Features by state:
#   AL: 20668
#   AR: 18729
#   AZ: 30627
#   CA: 55271
#   CO: 43797
#   CT: 1928
#   DC: 90
#   DE: 940
#   FL: 19882
#   GA: 20045
#   HI: 239
#   IA: 29001
#   ID: 39737
#   ID CA02: 6
#   IL: 28909
#   IN: 13467
#   KS: 34059
#   KY: 14429
#   LA: 16346
#   MA: 4037
#   MD: 5376
#   ME: 13763
#   ME NH: 1
#   MI: 24358
#   MN: 34250
#   MN CA03: 4
#   MO: 25414
#   MR: 1
#   MS: 19312
#   MT: 70529
#   MT CA02: 18
#   MT CA11: 2
#   MT ID CA02: 2
#   MX: 361
#   NC: 17878
#   ND: 49974
#   ND CA03: 28
#   ND MN CA03: 3
#   NE: 29087
#   NH: 4521
#   NJ: 2478
#   NM: 40394
#   NV: 29917
#   NY: 22773
#   NY CA10: 9
#   OH: 18424
#   OK: 24177
#   OP: 1
#   OR: 37353
#   PA: 13555
#   RI: 523
#   SC: 12738
#   SD: 36354
#   TN: 14699
#   TX: 86305
#   UT: 30480
#   UT AZ: 1
#   VA: 17910
#   VT: 4649
#   VT CA10: 20
#   VT NY CA10: 2
#   WA: 30605
#   WA CA02: 39
#   WI: 22402
#   WV: 9413
#   WY: 29870
#
# Output saved to: /ocean/projects/cis250156p/ppradhan/swank/naip_on_aws/naip_on_aws_all_states.gpkg
